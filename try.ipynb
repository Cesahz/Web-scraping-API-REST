# %%
#celda 1
# Hago las importaciones y asigno la conexion con la base de datos y activo la clave 
# foranea de SQLITE.

# %%
# -Agrego la url base de la web

# -Con esa url olicito al servidor acceder al contenido de esa url, luego el servidor
# me devuelve un response, el header con varios datos, entre ellos el numero de respuesta 
# como 200 si fue correcto o 404 si no se encontro etc, y el html de la pagina que usare

# -Luego convertimos el texto sucio del response a estructura html legible por python,
# basicamente para acceder a sus etiquetas etc.

# -Extrae todas las categorias y con un bucle lo guarda por nombre y url de la categoria

# -Inserta las categorias a la base de datos.

# -Crea cache para poder acceder luego al id a traves del nombre de la categoria y 
#usar la clave foranea.
